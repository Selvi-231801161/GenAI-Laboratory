# %% [markdown]
# <a href="https://colab.research.google.com/github/Selvi-231801161/GenAI-Laboratory/blob/main/GenAI_EXP_2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
import nltk
from gensim.models import Word2Vec
import numpy as np

corpus = [
    "The king rules the kingdom",
    "The queen rules the kingdom",
    "The prince is the son of the king"
]

processed_sentences = []

for sentence in corpus:
    words = sentence.lower().split()
    processed_sentences.append(words)

print("Tokenized Sentences:")
print(processed_sentences)

model = Word2Vec(
    sentences=processed_sentences,
    vector_size=100,
    window=3,
    min_count=1,
    sg=1
)

vocabulary = list(model.wv.index_to_key)

print("\nVocabulary Generated:")
print(vocabulary)

print("\nWord Embedding for 'king':")
print(model.wv['king'])

query_words = ["king", "queen", "city"]

for word in query_words:
    print(f"\nTop 5 words similar to '{word}':")

    if word in model.wv:
        similar_words = model.wv.most_similar(word, topn=5)

        for w, score in similar_words:
            print(w, ":", score)
    else:
        print("Word not in vocabulary")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 59.0 MB/s eta 0:00:00
# ...
# Tokenized Sentences:
# [['the', 'king', 'rules', 'the', 'kingdom'], ['the', 'queen', 'rules', 'the', 'kingdom'], ['the', 'prince', 'is', 'the', 'son', 'of', 'the', 'king']]
#
# Vocabulary Generated:
# ['the', 'kingdom', 'rules', 'king', 'of', 'son', 'is', 'prince', 'queen']
#
# Word Embedding for 'king':
# [-8.2434788e-03  9.3002589e-03 -1.9768013e-04 -1.9674676e-03
#   4.6040779e-03 -4.0957141e-03  2.7433808e-03  6.9406414e-03
#   6.0660155e-03 -7.5115245e-03  9.3832621e-03  4.6722624e-03
#   3.9665061e-03 -6.2441123e-03  8.4608020e-03 -2.1503740e-03
#   8.8260453e-03 -5.3625237e-03 -8.1302095e-03  6.8252226e-03
#   1.6713552e-03 -2.1987227e-03  9.5145255e-03  9.4947778e-03
#  -9.7749969e-03  2.5054722e-03  6.1572907e-03  3.8728330e-03
#   2.0229840e-03  4.3054356e-04  6.7369692e-04 -3.8210077e-03
#  -7.1409447e-03 -2.0890753e-03  3.9242790e-03  8.8195410e-03
# ...
