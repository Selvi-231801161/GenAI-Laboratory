# %% [markdown]
# <a href="https://colab.research.google.com/github/Selvi-231801161/GenAI-Laboratory/blob/main/GenAI_EXP_1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import random
from nltk.tag import hmm
from nltk.probability import LidstoneProbDist

train_data = [
    [("I", "PRP"), ("love", "VBP"), ("NLP", "NNP")],
    [("This", "DT"), ("is", "VBZ"), ("easy", "JJ")],
    [("Students", "NNS"), ("learn", "VBP"), ("AI", "NNP")]
]

for sentence in train_data:
    sentence.append(("UNK", "NN"))

random.shuffle(train_data)

estimator = lambda fd, bins: LidstoneProbDist(fd, 0.1, bins)

trainer = hmm.HiddenMarkovModelTrainer()
hmm_tagger = trainer.train(train_data, estimator=estimator)

sentence = "I love AI".split()
tagged_output = hmm_tagger.tag(sentence)

print("Tagged Sentence:")
print(tagged_output)
# Out:
# Tagged Sentence:
# [('I', 'PRP'), ('love', 'VBP'), ('AI', 'NNP')]
